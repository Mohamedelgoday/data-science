# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel('xlable')
plt.ylabel('ylable')
plt.title('TITLE')
# Out:
# Text(0.5,1,'TITLE')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')

# %%
plt.subplot(1,2,2)
plt.plot(x,y,'r')


plt.subplot(1,2,1)
plt.plot(y,x,'b')

# %%
fig=plt.figure()

# %%
axes=fig.add_axes([.1,.1,.8,.8])

# %%
fig

# %%
fig5=plt.figure()

# %%
fig5

# %%
fig

# %%
fig=plt.figure()
axes=fig.add_axes([.1,.1,.8,.8])
axes.plot(x,y,'b')
axes.set_xlabel('set x lable')
axes.set_ylabel('set y lable')
axes.set_title('set title')
# Out:
# Text(0.5,1,'set title')

# %%
fig=plt.figure()
axes1=fig.add_axes([.1,.1,.8,.8])
axes2=fig.add_axes([.2,.5,.4,.3])

#axes3=fig.add_axes([.4,.6,.7,.9])
#axes3.plot(x,y,'b')

axes1.plot(x,y,'r')
axes1.set_xlabel(' set x1 lable')
axes1.set_ylabel('aet y1 lable ')
axes1.set_title('set title 1')

axes2.plot(x,y,'g')
axes2.set_xlabel(' set x2 lable')
axes2.set_ylabel('aet y2 lable ')
axes2.set_title('set title 2');

# %%
fig,axes = plt.subplots(nrows=1, ncols=2)



#for current_ax in axes:
   # current_ax.plot(x,y)
    

    
axes[0].plot(x,y,'r')
axes[0].set_title('first')
axes[1].plot(y,x,'g')
axes[1].set_title('second')
plt.tight_layout()

# %%
fig, axes = plt.subplots(nrows=2,ncols=1,figsize=(10,3))

axes[0].plot(x, y, 'b')
axes[1].plot(x,y,'r')
plt.tight_layout()

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
fig=plt.figure()
axes=fig.add_axes([0,0,1,1])
axes.plot(x,x**2,label='x square')
axes.plot(x,x**3,label='x cubed')
axes.set_xlabel('x label')
axes.set_ylabel('y label')
axes.set_title('title')
axes.legend(loc=10)

# %%
fig.savefig('my pic.png',dpi=200)

# %%
fig

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y,'b',linewidth=3,alpha=.8,linestyle='-',marker='o',markersize=5)

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
